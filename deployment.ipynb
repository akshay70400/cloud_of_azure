# %% [markdown]
# ### <mark>Challenges with deployment

# %% [raw]
# 1. Scalability
# 2. Data drift
# 3. Model drift (due to change in data)
# 4. monitoring
# 5. security

# %% [raw]
# ### On-Premise vs cloud deployment

# %% [raw]
# Project 1: MCO POC
# Flask, Docker
#
# Project 2: MicroSeg
# Flask, Docker, AKS

# %% [markdown]
# ### <mark> AzureML

# %% [markdown]
# ### <mark> Docker

# %% [raw]
# Docker file -
# Dockr image -
# Docker container - an instance of docker image
# Docker engine - converts containers into indivisual entities
#
# docker file example :
#
# You dont want prerequisites and os level dependencies to harm you application.
# Docker is a manual service, so managing the containers and to work with multiple containers is tricky here so we can use kubernetes here to manage and run docker images on kubernetes clusters.
#
# we have images -> managed by kubernetes -> running on azure platform

# %% [markdown]
# ![image.png](attachment:1d54a78f-ea73-4617-be02-e749625f8927.png)

# %% [markdown]
# ### <mark> Kubernetes

# %% [markdown]
# ### <mark> DEPLOYMENT ON AZURE USNG Flask, Github Actions, Azure

# %% [raw]
# 1. Create your application using flask in VS code
# 2. Push your code to Github
# 3. Create a web app service on azure (establish connection with your github project repository)
# 4. Deployment shall happen automatically
# 5. In github repo, automatically a .github/workflow/main.yml folder will be created containing a yaml file main_gempriceprediction.yml
# 6. In github -> secrets and variables -> Repository secret
# this information/secret is being read in above yaml file
# 7. On github -> Actions -> build and deploy
# Build: (based on above yaml file)
#     setup jobs
#     run actions/checkout@v2 --> synking and initializing repository
#     setup python version
#     create and start virtual environment
#     install dependencies
#     upload artefact for deployment job - in zip file
#     post run actions
#     complete job
# Deploy:
#     set up job
#     download artefact from build job
#     deploy to azure web app
#     complete job
#     (you will get deployment url)

# %% [markdown]
# ### <mark>  DEPLOYMENT ON AWS EC2 using Streamlit, AWS EC2

# %% [raw]
# 1.
# 2.
# 3.

# %% [markdown]
# ### <mark> On Premise deployment using Docker

# %% [raw]
# 1.
# 2.
# 3.

# %% [markdown]
# ### <mark> Deployment using Flask, Docker and AzureAKS(Kubernetes)

# %% [raw]
# Files needed in repository:
#     Dockerfile
#     models/model.pkl
#     requirements.txt
#     scripts/app.py
#     deployment.yaml

# %% [raw]
# AKS - Runs the docker containers, self managed service that manages cluster required servers. And your endpoints are given to the end users.
# Automated management and scalability of Kubernetes clusters for enterprise-grade container orchestration. End-to-end developer productivity with debugging, CI/CD, logging. Advanced identity and access management to monitor and maintain container security for governance at scale.Support for Linux, Windows Server, and IoT resources with AKS deployment on the infrastructure of your choice using Azure Arc.
#
# 1.
# 2.
# 3. Create a docker file and dockerize the model and verify it on local instance.
# 4. Docker image was registered on container service of azure i.e., Azure container registry.

# %% [raw]
# Model deployment with azure steps:
# 1. create resource group
# 2. create azure container registry
#     carsvm -> access keys -> enable admin user -> username, password
# 3. Login to container registry and tag the image
# 4. push the image
# 5. create aks cluster
# 6. get AKS cluster credentials
# 7. create pods and services
# 8. deploy using yaml file

# %% [markdown]
# ![image.png](attachment:c8c84bf3-1e25-40bf-98e3-25cd210889be.png)

# %% [markdown]
# ### <mark> PROJECT REPOSITORY CONTAINS:

# %% [raw]
# .gitignore
# readme.md
# requirements.txt
# docker
# artefacts
# main.py
# setup.py
# .sh file

# %% [raw]
# artefacts: Deployment artifacts are packages that contain all the necessary components required to deploy your application code to a specific environment. These artifacts can include source code, configuration files, dependencies, and any other assets required to run your application.

# %% [raw]
# # setup.py
#
# In Python, setup.py is a module used to build and distribute Python packages. It typically contains information about the package, such as its name, version, and dependencies, as well as instructions for building and installing the package.

# %% [raw]
# from setuptools import find_packages, setup
# from typing import List
#
# HYPHEN_E_DOT = '-e .'
#
# def get_requirements(file_path:str)->List[str]:
#     '''
#     This function will return list of requirements
#     from requirements.txt file
#     '''
#     # Initializing blank requirements list
#     requirements = []
#
#     # Opening the file
#     with open(file_path) as file_obj:
#         requirements = file_obj.readlines()
#         requirements = [req.replace("\n","") for req in requirements]
#
#         # Remove hyphen_e_dot if present in requirements
#         if HYPHEN_E_DOT in requirements:
#             requirements.remove(HYPHEN_E_DOT)
#
#     return requirements
#
# setup(
#     name = 'mlproject_regression',
#     version= '0.0.1',
#     author=Jack Ronie',
#     author_email='JackRonie@gmail.com',
#     packages = find_packages(),
#     install_requires = get_requirements('requirements.txt')
# )

# %% [raw]
# # .sh file
